# %%
import numpy as np

# %%
cm = 50505.1
sec = 1.51976e15
TiNexp = 1.33328e50

# %%
from matplotlib.ticker import LogLocator
import matplotlib.pyplot as plt

#plt.style.use('/Users/koichiro/Dropbox/GraduateResearch/quantumSensor/physrev.mplstyle')
#plt.style.use('/Users/koichiromacmini/Dropbox/GraduateResearch/quantumSensor/physrev.mplstyle')
#plt.style.use('/Users/koichiromacstudio/Dropbox/GraduateResearch/quantumSensor/physrev.mplstyle')

# %% [markdown]
# # Cutting

# %%
input_path = 'TiN_R10_q0M1.csv'
output_path = 'TiN_R10_q0M1_Ko_thresholded.csv'

with open(input_path, 'r') as f:
    lines = f.readlines()

# 各行をfloatのリストに変換
rows = []
for line in lines:
    vals = [float(v) for v in line.strip().split(',')]
    rows.append(vals)

# 各行の最大値の1e-4倍より小さい値を0にする
new_rows = []
for row in rows:
    row_max = max(row)
    threshold = row_max * 1e-2
    new_row = [v if v >= threshold else 0.0 for v in row]
    new_rows.append(new_row)

# 出力
with open(output_path, 'w') as f:
    for row in new_rows:
        f.write(','.join(f'{v:.6e}' for v in row) + '\n')

# %%
np.sum(new_rows)/np.sum(rows)
# Out:
# np.float64(0.9859956109157934)

# %%
input_path = 'TiN_R10_q0M2.csv'
output_path = 'TiN_R10_q0M2_Ko_thresholded.csv'

with open(input_path, 'r') as f:
    lines = f.readlines()

# 各行をfloatのリストに変換
rows = []
for line in lines:
    vals = [float(v) for v in line.strip().split(',')]
    rows.append(vals)

# 各行の最大値の1e-4倍より小さい値を0にする
new_rows = []
for row in rows:
    row_max = max(row)
    threshold = row_max * 1e-2
    new_row = [v if v >= threshold else 0.0 for v in row]
    new_rows.append(new_row)

# 出力
with open(output_path, 'w') as f:
    for row in new_rows:
        f.write(','.join(f'{v:.6e}' for v in row) + '\n')

# %%
np.sum(new_rows)/np.sum(rows)
# Out:
# np.float64(0.9886564771055665)

# %%
input_path = 'TiN_R10_q0M3.csv'
output_path = 'TiN_R10_q0M3_Ko_thresholded.csv'

with open(input_path, 'r') as f:
    lines = f.readlines()

# 各行をfloatのリストに変換
rows = []
for line in lines:
    vals = [float(v) for v in line.strip().split(',')]
    rows.append(vals)

# 各行の最大値の1e-4倍より小さい値を0にする
new_rows = []
for row in rows:
    row_max = max(row)
    threshold = row_max * 1e-2
    new_row = [v if v >= threshold else 0.0 for v in row]
    new_rows.append(new_row)

# 出力
with open(output_path, 'w') as f:
    for row in new_rows:
        f.write(','.join(f'{v:.6e}' for v in row) + '\n')

# %%
np.sum(new_rows)/np.sum(rows)
# Out:
# np.float64(0.9880748989043162)

# %% [markdown]
# # Refined exposure

# %%
input_path = 'TiN_R10_q0M1_Ko_thresholded.csv'
output_path = 'TiN_R10_q0M1_Ko_thresholded_refined_exposure.csv'

with open(input_path, 'r') as f:
    lines = f.readlines()

# 各行をfloatのリストに変換
rows = []
for line in lines:
    vals = [float(v) * TiNexp for v in line.strip().split(',')]
    rows.append(vals)

# 各行の最大値の1e-4倍より小さい値を0にする
new_rows = []
for row in rows:
    row_max = max(row)
    threshold = row_max * 1e-2
    new_row = [v if v >= threshold else 0.0 for v in row]
    new_rows.append(new_row[60:259])

# 出力
with open(output_path, 'w') as f:
    for row in new_rows:
        f.write(','.join(f'{v:.6e}' for v in row) + '\n')

# %%
input_path = 'TiN_R10_q0M2_Ko_thresholded.csv'
output_path = 'TiN_R10_q0M2_Ko_thresholded_refined_exposure.csv'

with open(input_path, 'r') as f:
    lines = f.readlines()

# 各行をfloatのリストに変換
rows = []
for line in lines:
    vals = [float(v) * TiNexp for v in line.strip().split(',')]
    rows.append(vals)

# 各行の最大値の1e-4倍より小さい値を0にする
new_rows = []
for row in rows:
    row_max = max(row)
    threshold = row_max * 1e-2
    new_row = [v if v >= threshold else 0.0 for v in row]
    new_rows.append(new_row[19:249])

# 出力
with open(output_path, 'w') as f:
    for row in new_rows:
        f.write(','.join(f'{v:.6e}' for v in row) + '\n')

# %%
input_path = 'TiN_R10_q0M3_Ko_thresholded.csv'
output_path = 'TiN_R10_q0M3_Ko_thresholded_refined_exposure.csv'

with open(input_path, 'r') as f:
    lines = f.readlines()

# 各行をfloatのリストに変換
rows = []
for line in lines:
    vals = [float(v) * TiNexp for v in line.strip().split(',')]
    rows.append(vals)

# 各行の最大値の1e-4倍より小さい値を0にする
new_rows = []
for row in rows:
    row_max = max(row)
    threshold = row_max * 1e-2
    new_row = [v if v >= threshold else 0.0 for v in row]
    new_rows.append(new_row[10:248])

# 出力
with open(output_path, 'w') as f:
    for row in new_rows:
        f.write(','.join(f'{v:.6e}' for v in row) + '\n')

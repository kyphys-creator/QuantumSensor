# %% [markdown]
# ### Imports

# %%
import numpy as np
from scipy.optimize import minimize, LinearConstraint
from scipy import integrate
from scipy.sparse import csc_matrix
import time
import matplotlib.pyplot as plt
import pandas as pd
from numba import jit, njit
from quantum_sensor import NeutrinoAnalysis
from matplotlib.ticker import LogLocator

# plt.style.use('/Users/koichiro/Dropbox/GraduateResearch/quantumSensor/physrev.mplstyle')
#plt.style.use('/Users/koichiromacmini/Dropbox/GraduateResearch/quantumSensor/physrev.mplstyle')
#plt.style.use('/Users/koichiromacstudio/Dropbox/GraduateResearch/quantumSensor/physrev.mplstyle')

# %% [markdown]
# # Transition Edge Sensor

# %%
import numpy as np
from scipy.optimize import minimize, LinearConstraint
from scipy import integrate
from scipy.sparse import csc_matrix
import time
import matplotlib.pyplot as plt
import pandas as pd
from numba import jit, njit
from quantum_sensor import NeutrinoAnalysis
# This block defines the main workflow of the script.
# It will only run when the script is executed directly.
# 1. Initialize the analysis class with a specific background scenario
analysis_none = NeutrinoAnalysis(background_scenario='none', material = 'Al', mass = '1', q= '0', cons1 = 1, cons2 = 1e30)#cons1 = 1, cons2 = 9e35, cons1 = 1, cons2 = 8e35, cons1 = 1, cons2 = 5e35, cons1 = 2e33, cons2 = 4e62
# 2. Run the main optimization.
print("--- Running main optimization for background 'none' ---")
result_none = analysis_none.optimize(analysis_none.data_vector, solver = 'osqp')

# 3. Plot the primary result: the optimized flux vs. theory.
analysis_none.plot_eta_comparison()
plt.ylim(0, 10e-26)
plt.rcParams["font.size"] = 10
plt.rcParams['figure.dpi'] = "300"

#plt.gca().yaxis.set_major_locator(LogLocator(base=10.0, subs=None, numticks=40))
plt.gca().yaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(1.0, 10) * 0.1, numticks=20))
plt.gca().xaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(1.0, 10) * 0.1, numticks=20))

plt.tick_params(axis='both', which='major', labelsize=20)
plt.tick_params(axis='both', which='minor', labelsize=20)
plt.title(r'TES(Al): $m_\chi = 10$ MeV', fontsize=20)

plt.savefig('results/TES_10MeV_q=0_SHM.pdf')
# Out:
# --- Running main optimization for background 'none' ---
# Plot saved as /Users/koichiromacstudio/Documents/Claude/QuantumSensor/TES_clean10/results/scenario_bkg_none/flux10_none_AlM1q0.pdf

# %%
result_none.x /analysis_none.cons2 * analysis_none.cons1 * analysis_none.cm
# Out:
# array([4.56405379e-26, 4.56405379e-26, 4.56405379e-26, 4.56405379e-26,
#        4.56405379e-26, 4.56405379e-26, 4.56405379e-26, 4.56405379e-26,
#        4.56405379e-26, 4.56405379e-26, 4.56405379e-26, 4.56405379e-26,
#        4.56405379e-26, 4.56405379e-26, 4.56405379e-26, 4.56405379e-26,
#        4.56405379e-26, 4.56405379e-26, 4.56405379e-26, 4.56405379e-26,
#        4.56405379e-26, 4.56405379e-26, 4.56405379e-26, 4.56405379e-26,
#        4.56405379e-26, 4.56405379e-26, 4.56405379e-26, 4.56405379e-26,
#        4.50261391e-26, 4.50261391e-26, 4.50261391e-26, 4.50261391e-26,
#        4.50261391e-26, 4.50261391e-26, 4.50261391e-26, 4.50261391e-26,
#        4.50261391e-26, 4.50261391e-26, 4.50261391e-26, 4.47481241e-26,
#        4.47481241e-26, 4.47481241e-26, 4.47481241e-26, 4.47481241e-26,
#        4.47481241e-26, 4.47481241e-26, 4.47481241e-26, 4.42808401e-26,
#        4.42808401e-26, 4.42808401e-26, 4.36309136e-26, 4.36309136e-26,
#        4.36309136e-26, 4.36309136e-26, 4.36309136e-26, 4.36309136e-26,
#        4.36309136e-26, 4.36309136e-26, 4.36309136e-26, 4.36309136e-26,
#        4.36309136e-26, 4.36309136e-26, 4.32424941e-26, 4.32424941e-26,
#        4.32424941e-26, 4.32424941e-26, 4.32424941e-26, 4.32424941e-26,
#        4.32424941e-26, 4.28027826e-26, 4.28027826e-26, 4.28027826e-26,
#        4.28027826e-26, 4.28027826e-26, 4.28027826e-26, 4.28027826e-26,
#        4.28027826e-26, 4.28027826e-26, 4.28027826e-26, 4.28027826e-26,
#        4.28027826e-26, 4.24176005e-26, 4.15942130e-26, 4.15942130e-26,
#        4.15942130e-26, 4.15942130e-26, 4.15942130e-26, 4.15942130e-26,
#        4.15942130e-26, 4.15942130e-26, 4.15942130e-26, 4.15942130e-26,
#        4.15942130e-26, 4.15942130e-26, 4.15942130e-26, 4.15942130e-26,
#        4.15942130e-26, 4.15942130e-26, 4.15942130e-26, 4.15942130e-26,
#        4.15942130e-26, 4.15942130e-26, 4.15942130e-26, 4.15942130e-26,
#        4.15942130e-26, 4.15942130e-26, 4.15942130e-26, 4.15942130e-26,
#        4.15942130e-26, 4.15942130e-26, 4.15942130e-26, 4.15942130e-26,
#        4.15942130e-26, 4.15942130e-26, 4.15942130e-26, 4.15942130e-26,
#        4.15942130e-26, 4.15942130e-26, 4.15942130e-26, 4.15942130e-26,
#        4.15942130e-26, 4.15942130e-26, 4.15942130e-26, 4.15942130e-26,
#        2.56255194e-26, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00])

# %%
np.shape(analysis_none.CRmat)
# Out:
# (10, 491)

# %%
analysis_none.CRmat@analysis_none.fig1Solid[44:535]/analysis_none.cm
# Out:
# array([2.21618440e-05, 3.76019884e-05, 5.22317458e-05, 6.67575103e-05,
#        8.02395055e-05, 9.35824592e-05, 1.06952663e-04, 1.20585715e-04,
#        1.31657992e-04, 1.43005441e-04])

# %%
import numpy as np
from scipy.optimize import minimize, LinearConstraint
from scipy import integrate
from scipy.sparse import csc_matrix
import time
import matplotlib.pyplot as plt
import pandas as pd
from numba import jit, njit
from quantum_sensor import NeutrinoAnalysis
# This block defines the main workflow of the script.
# It will only run when the script is executed directly.
# 1. Initialize the analysis class with a specific background scenario
analysis_none = NeutrinoAnalysis(background_scenario='none', material = 'Al', mass = '2', q= '0', cons1 = 1, cons2 = 1e32)#cons1 = 1, cons2 = 9e35, cons1 = 1, cons2 = 8e35, cons1 = 1, cons2 = 5e35, cons1 = 2e33, cons2 = 4e62
# 2. Run the main optimization.
print("--- Running main optimization for background 'none' ---")
result_none = analysis_none.optimize(analysis_none.data_vector, solver = 'osqp')

# 3. Plot the primary result: the optimized flux vs. theory.
analysis_none.plot_eta_comparison()
plt.ylim(0, 10e-27)
plt.rcParams["font.size"] = 10
plt.rcParams['figure.dpi'] = "300"

#plt.gca().yaxis.set_major_locator(LogLocator(base=10.0, subs=None, numticks=40))
plt.gca().yaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(1.0, 10) * 0.1, numticks=20))
plt.gca().xaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(1.0, 10) * 0.1, numticks=20))

plt.tick_params(axis='both', which='major', labelsize=20)
plt.tick_params(axis='both', which='minor', labelsize=20)
plt.title(r'TES(Al): $m_\chi = 10$ MeV', fontsize=20)

plt.savefig('results/TES_10MeV_q=0_SHM.pdf')
# Out:
# --- Running main optimization for background 'none' ---
# Plot saved as /Users/koichiromacstudio/Documents/Claude/QuantumSensor/TES_clean10/results/scenario_bkg_none/flux10_none_AlM2q0.pdf

# %%
analysis_none.CRmat@analysis_none.fig1Solid[13:129]/analysis_none.cm
# Out:
# array([2.40932716e-06, 4.23388697e-06, 5.98922178e-06, 7.60250340e-06,
#        9.28210056e-06, 1.09164251e-05, 1.25429008e-05, 1.41785864e-05,
#        1.57599937e-05, 1.72220288e-05])

# %%
import numpy as np
from scipy.optimize import minimize, LinearConstraint
from scipy import integrate
from scipy.sparse import csc_matrix
import time
import matplotlib.pyplot as plt
import pandas as pd
from numba import jit, njit
from quantum_sensor import NeutrinoAnalysis
# This block defines the main workflow of the script.
# It will only run when the script is executed directly.
# 1. Initialize the analysis class with a specific background scenario
analysis_none = NeutrinoAnalysis(background_scenario='none', material = 'Al', mass = '3', q= '0', cons1 = 1, cons2 = 1e30)#cons1 = 1, cons2 = 9e35, cons1 = 1, cons2 = 8e35, cons1 = 1, cons2 = 5e35, cons1 = 2e33, cons2 = 4e62
# 2. Run the main optimization.
print("--- Running main optimization for background 'none' ---")
result_none = analysis_none.optimize(analysis_none.data_vector, solver = 'osqp')

# 3. Plot the primary result: the optimized flux vs. theory.
analysis_none.plot_eta_comparison()
plt.ylim(0, 10e-28)
plt.rcParams["font.size"] = 10
plt.rcParams['figure.dpi'] = "300"

#plt.gca().yaxis.set_major_locator(LogLocator(base=10.0, subs=None, numticks=40))
plt.gca().yaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(1.0, 10) * 0.1, numticks=20))
plt.gca().xaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(1.0, 10) * 0.1, numticks=20))

plt.tick_params(axis='both', which='major', labelsize=20)
plt.tick_params(axis='both', which='minor', labelsize=20)
plt.title(r'TES(Al): $m_\chi = 10$ MeV', fontsize=20)

plt.savefig('results/TES_10MeV_q=0_SHM.pdf')
# Out:
# --- Running main optimization for background 'none' ---
# Plot saved as /Users/koichiromacstudio/Documents/Claude/QuantumSensor/TES_clean10/results/scenario_bkg_none/flux10_none_AlM3q0.pdf

# %%
analysis_none.CRmat@analysis_none.fig1Solid[4:128]/analysis_none.cm
# Out:
# array([2.53233407e-07, 4.13902443e-07, 5.77745405e-07, 7.53748359e-07,
#        9.24681845e-07, 1.09045455e-06, 1.25532613e-06, 1.41879890e-06,
#        1.57954820e-06, 1.72969733e-06])

# %%
import numpy as np
from scipy.optimize import minimize, LinearConstraint
from scipy import integrate
from scipy.sparse import csc_matrix
import time
import matplotlib.pyplot as plt
import pandas as pd
from numba import jit, njit
from quantum_sensor import NeutrinoAnalysis
# This block defines the main workflow of the script.
# It will only run when the script is executed directly.
# 1. Initialize the analysis class with a specific background scenario
analysis_none = NeutrinoAnalysis(background_scenario='none', material = 'TiN', mass = '1', q= '0', cons1 = 1, cons2 = 1e30)#cons1 = 1, cons2 = 9e35, cons1 = 1, cons2 = 8e35, cons1 = 1, cons2 = 5e35, cons1 = 2e33, cons2 = 4e62
# 2. Run the main optimization.
print("--- Running main optimization for background 'none' ---")
result_none = analysis_none.optimize(analysis_none.data_vector, solver = 'osqp')

# 3. Plot the primary result: the optimized flux vs. theory.
analysis_none.plot_eta_comparison()
plt.ylim(0, 10e-26)
plt.rcParams["font.size"] = 10
plt.rcParams['figure.dpi'] = "300"

#plt.gca().yaxis.set_major_locator(LogLocator(base=10.0, subs=None, numticks=40))
plt.gca().yaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(1.0, 10) * 0.1, numticks=20))
plt.gca().xaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(1.0, 10) * 0.1, numticks=20))

plt.tick_params(axis='both', which='major', labelsize=20)
plt.tick_params(axis='both', which='minor', labelsize=20)
plt.title(r'MKID(TiN): $m_\chi = 10$ MeV', fontsize=20)

plt.savefig('results/MKID_10MeV_q=0_SHM.pdf')
# Out:
# --- Running main optimization for background 'none' ---
# Plot saved as /Users/koichiromacstudio/Documents/Claude/QuantumSensor/TES_clean10/results/scenario_bkg_none/flux10_none_TiNM1q0.pdf

# %%
analysis_none.CRmat@analysis_none.fig1Solid[60:259]/analysis_none.cm
# Out:
# array([ 628165.78580323,  944302.08706412, 1192015.8916106 ,
#        1473831.22647551, 1738171.87423287, 1931879.5932421 ,
#        2141759.16143276, 2347466.98482489, 2523023.26949205])

# %%
import numpy as np
from scipy.optimize import minimize, LinearConstraint
from scipy import integrate
from scipy.sparse import csc_matrix
import time
import matplotlib.pyplot as plt
import pandas as pd
from numba import jit, njit
from quantum_sensor import NeutrinoAnalysis
# This block defines the main workflow of the script.
# It will only run when the script is executed directly.
# 1. Initialize the analysis class with a specific background scenario
analysis_none = NeutrinoAnalysis(background_scenario='none', material = 'TiN', mass = '2', q= '0', cons1 = 1, cons2 = 1e30)#cons1 = 1, cons2 = 9e35, cons1 = 1, cons2 = 8e35, cons1 = 1, cons2 = 5e35, cons1 = 2e33, cons2 = 4e62
# 2. Run the main optimization.
print("--- Running main optimization for background 'none' ---")
result_none = analysis_none.optimize(analysis_none.data_vector, solver = 'osqp')

# 3. Plot the primary result: the optimized flux vs. theory.
analysis_none.plot_eta_comparison()
plt.ylim(0, 10e-27)
plt.rcParams["font.size"] = 10
plt.rcParams['figure.dpi'] = "300"

#plt.gca().yaxis.set_major_locator(LogLocator(base=10.0, subs=None, numticks=40))
plt.gca().yaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(1.0, 10) * 0.1, numticks=20))
plt.gca().xaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(1.0, 10) * 0.1, numticks=20))

plt.tick_params(axis='both', which='major', labelsize=20)
plt.tick_params(axis='both', which='minor', labelsize=20)
plt.title(r'MKID(TiN): $m_\chi = 100$ MeV', fontsize=20)

plt.savefig('results/MKID_10MeV_q=0_SHM.pdf')
# Out:
# --- Running main optimization for background 'none' ---
# Plot saved as /Users/koichiromacstudio/Documents/Claude/QuantumSensor/TES_clean10/results/scenario_bkg_none/flux10_none_TiNM2q0.pdf

# %%
analysis_none.CRmat@analysis_none.fig1Solid[19:249]/analysis_none.cm
# Out:
# array([ 60352.84361969,  92911.70105689, 118580.86241321, 143600.09958097,
#        167840.27879991, 191249.75966479, 213622.22822558, 234944.88764685,
#        254811.53584432])

# %%
import numpy as np
from scipy.optimize import minimize, LinearConstraint
from scipy import integrate
from scipy.sparse import csc_matrix
import time
import matplotlib.pyplot as plt
import pandas as pd
from numba import jit, njit
from quantum_sensor import NeutrinoAnalysis
# This block defines the main workflow of the script.
# It will only run when the script is executed directly.
# 1. Initialize the analysis class with a specific background scenario
analysis_none = NeutrinoAnalysis(background_scenario='none', material = 'TiN', mass = '3', q= '0', cons1 = 1, cons2 = 1e30)#cons1 = 1, cons2 = 9e35, cons1 = 1, cons2 = 8e35, cons1 = 1, cons2 = 5e35, cons1 = 2e33, cons2 = 4e62
# 2. Run the main optimization.
print("--- Running main optimization for background 'none' ---")
result_none = analysis_none.optimize(analysis_none.data_vector, solver = 'osqp')

# 3. Plot the primary result: the optimized flux vs. theory.
analysis_none.plot_eta_comparison()
plt.ylim(0, 10e-28)
plt.rcParams["font.size"] = 10
plt.rcParams['figure.dpi'] = "300"

#plt.gca().yaxis.set_major_locator(LogLocator(base=10.0, subs=None, numticks=40))
plt.gca().yaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(1.0, 10) * 0.1, numticks=20))
plt.gca().xaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(1.0, 10) * 0.1, numticks=20))

plt.tick_params(axis='both', which='major', labelsize=20)
plt.tick_params(axis='both', which='minor', labelsize=20)
plt.title(r'MKID(TiN): $m_\chi = 1000$ MeV', fontsize=20)

plt.savefig('results/TES_10MeV_q=0_SHM.pdf')
# Out:
# --- Running main optimization for background 'none' ---
# Plot saved as /Users/koichiromacstudio/Documents/Claude/QuantumSensor/TES_clean10/results/scenario_bkg_none/flux10_none_TiNM3q0.pdf

# %%
analysis_none.CRmat@analysis_none.fig1Solid[10:248]/analysis_none.cm
# Out:
# array([ 5992.56228467,  9223.8001347 , 11781.97297371, 14275.51218766,
#        16697.24239414, 19035.70353802, 21283.57940527, 23423.3304936 ,
#        25420.1071373 ])

# %% [markdown]
# # Bound

# %%
import numpy as np
from scipy.optimize import minimize, LinearConstraint
from scipy import integrate
from scipy.sparse import csc_matrix
import time
import matplotlib.pyplot as plt
import pandas as pd
from numba import jit, njit
from quantum_sensor import NeutrinoAnalysis
# This block defines the main workflow of the script.
# It will only run when the script is executed directly.
# 1. Initialize the analysis class with a specific background scenario
analysis_none = NeutrinoAnalysis(background_scenario='none', eta = 'Bound', material = 'Al', mass = '3', q= '0', cons1 = 1, cons2 = 1e30)#cons1 = 1, cons2 = 9e35, cons1 = 1, cons2 = 8e35, cons1 = 1, cons2 = 5e35, cons1 = 2e33, cons2 = 4e62
# 2. Run the main optimization.
print("--- Running main optimization for background 'none' ---")
result_none = analysis_none.optimize(analysis_none.data_vector, solver = 'osqp')

# 3. Plot the primary result: the optimized flux vs. theory.
analysis_none.plot_eta_comparison()
#plt.ylim(0, 1e-15)
plt.yscale('log')
plt.yscale
plt.rcParams["font.size"] = 10
plt.rcParams['figure.dpi'] = "300"

#plt.gca().yaxis.set_major_locator(LogLocator(base=10.0, subs=None, numticks=40))
plt.gca().yaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(1.0, 10) * 0.1, numticks=20))
plt.gca().xaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(1.0, 10) * 0.1, numticks=20))

plt.tick_params(axis='both', which='major', labelsize=20)
plt.tick_params(axis='both', which='minor', labelsize=20)
plt.title(r'TES(Al): $m_\chi = 1000$ MeV', fontsize=20)

plt.savefig('results/TES_10MeV_q=0_SHM.pdf')
# Out:
# --- Running main optimization for background 'none' ---
# Plot saved as /Users/koichiromacstudio/Documents/Claude/QuantumSensor/TES_clean10/results/scenario_bkg_none/flux10_none_AlM3q0.pdf

# %%
analysis_none.CRmat@analysis_none.fig1Solid[4:128]/analysis_none.cm
# Out:
# array([3.97037293e+02, 1.91420315e+01, 2.53335092e-01, 6.81500471e-03,
#        1.12714217e-04, 1.81848688e-06, 1.29093560e-06, 1.41879890e-06,
#        1.57954820e-06, 1.72969733e-06])

# %%
import numpy as np
from scipy.optimize import minimize, LinearConstraint
from scipy import integrate
from scipy.sparse import csc_matrix
import time
import matplotlib.pyplot as plt
import pandas as pd
from numba import jit, njit
from quantum_sensor import NeutrinoAnalysis
# This block defines the main workflow of the script.
# It will only run when the script is executed directly.
# 1. Initialize the analysis class with a specific background scenario
analysis_none = NeutrinoAnalysis(background_scenario='none', eta = 'Bound', material = 'TiN', mass = '3', q= '0', cons1 = 1, cons2 = 1e37)#cons1 = 1, cons2 = 9e35, cons1 = 1, cons2 = 8e35, cons1 = 1, cons2 = 5e35, cons1 = 2e33, cons2 = 4e62
# 2. Run the main optimization.
print("--- Running main optimization for background 'none' ---")
result_none = analysis_none.optimize(analysis_none.data_vector, solver = 'osqp')

# 3. Plot the primary result: the optimized flux vs. theory.
analysis_none.plot_eta_comparison()
#plt.ylim(0, 1e-15)
plt.yscale('log')
plt.yscale
plt.rcParams["font.size"] = 10
plt.rcParams['figure.dpi'] = "300"

#plt.gca().yaxis.set_major_locator(LogLocator(base=10.0, subs=None, numticks=40))
plt.gca().yaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(1.0, 10) * 0.1, numticks=20))
plt.gca().xaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(1.0, 10) * 0.1, numticks=20))

plt.tick_params(axis='both', which='major', labelsize=20)
plt.tick_params(axis='both', which='minor', labelsize=20)
plt.title(r'MKID(TiN): $m_\chi = 1000$ MeV', fontsize=20)

plt.savefig('results/TES_10MeV_q=0_SHM.pdf')
# Out:
# --- Running main optimization for background 'none' ---
# Plot saved as /Users/koichiromacstudio/Documents/Claude/QuantumSensor/TES_clean10/results/scenario_bkg_none/flux10_none_TiNM3q0.pdf

# %%
analysis_none.CRmat@analysis_none.fig1Solid[10:248]/analysis_none.cm
# Out:
# array([ 6041.21901789,  9223.8001347 , 11781.97297371, 14275.51218766,
#        16697.24239414, 19035.70353802, 21283.57940527, 23423.3304936 ,
#        25420.1071373 ])
